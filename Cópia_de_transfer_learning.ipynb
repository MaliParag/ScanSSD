# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import tensorflow as tf

# %%
tf.__version__
# Out:
# '2.8.2'

# %% [markdown]
# ## Data preprocessing

# %% [markdown]
# ### Data download

# %% [markdown]
# In this tutorial, you will use a dataset containing several thousand images of cats and dogs. Download and extract a zip file containing the images, then create a `tf.data.Dataset` for training and validation using the `tf.keras.utils.image_dataset_from_directory` utility. You can learn more about loading images in this [tutorial](https://www.tensorflow.org/tutorials/load_data/images).

# %%
PATH ='/content'

train_dir = os.path.join(PATH, 'train')
validation_dir = os.path.join(PATH, 'test')

BATCH_SIZE = 16
IMG_SIZE = (640, 640)

train_dataset = tf.keras.utils.image_dataset_from_directory(train_dir,
                                                            shuffle=True,
                                                            batch_size=BATCH_SIZE,
                                                            label_mode='categorical',
                                                            image_size=IMG_SIZE)
# Out:
# Found 240 files belonging to 6 classes.

# %%
validation_dataset = tf.keras.utils.image_dataset_from_directory(validation_dir,
                                                                 shuffle=True,
                                                                 batch_size=BATCH_SIZE,
                                                                 label_mode='categorical',
                                                                 image_size=IMG_SIZE)
# Out:
# Found 60 files belonging to 6 classes.

# %% [markdown]
# Show the first nine images and labels from the training set:

# %%
class_names = train_dataset.class_names

class_names
# Out:
# ['differentiation', 'finite', 'inequality', 'integral', 'limit', 'linear']

# %%
class_names = train_dataset.class_names

plt.figure(figsize=(10, 10))
for images, labels in train_dataset.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[np.argmax(labels[i])])
    plt.axis("off")

# %% [markdown]
# As the original dataset doesn't contain a test set, you will create one. To do so, determine how many batches of data are available in the validation set using `tf.data.experimental.cardinality`, then move 20% of them to a test set.

# %%
val_batches = tf.data.experimental.cardinality(validation_dataset)
test_dataset = validation_dataset.take(val_batches // 3)
validation_dataset = validation_dataset.skip(val_batches // 5)

# %%
print('Number of validation batches: %d' % tf.data.experimental.cardinality(validation_dataset))
print('Number of test batches: %d' % tf.data.experimental.cardinality(test_dataset))
# Out:
# Number of validation batches: 4
# Number of test batches: 1

# %% [markdown]
# ### Configure the dataset for performance

# %% [markdown]
# Use buffered prefetching to load images from disk without having I/O become blocking. To learn more about this method see the [data performance](https://www.tensorflow.org/guide/data_performance) guide.

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_dataset = train_dataset.prefetch(buffer_size=AUTOTUNE)
validation_dataset = validation_dataset.prefetch(buffer_size=AUTOTUNE)
test_dataset = test_dataset.prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ### Use data augmentation

# %% [markdown]
# When you don't have a large image dataset, it's a good practice to artificially introduce sample diversity by applying random, yet realistic, transformations to the training images, such as rotation and horizontal flipping. This helps expose the model to different aspects of the training data and reduce [overfitting](https://www.tensorflow.org/tutorials/keras/overfit_and_underfit). You can learn more about data augmentation in this [tutorial](https://www.tensorflow.org/tutorials/images/data_augmentation).

# %%
data_augmentation = tf.keras.Sequential([
  tf.keras.layers.RandomFlip('horizontal'),
  tf.keras.layers.RandomRotation(0.2),
])

# %% [markdown]
# Note: These layers are active only during training, when you call `Model.fit`. They are inactive when the model is used in inference mode in `Model.evaluate` or `Model.fit`.

# %% [markdown]
# Let's repeatedly apply these layers to the same image and see the result.

# %%
for image, _ in train_dataset.take(1):
  plt.figure(figsize=(10, 10))
  first_image = image[0]
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    augmented_image = data_augmentation(tf.expand_dims(first_image, 0))
    plt.imshow(augmented_image[0] / 255)
    plt.axis('off')

# %% [markdown]
# ### Rescale pixel values
#
# In a moment, you will download `tf.keras.applications.MobileNetV2` for use as your base model. This model expects pixel values in `[-1, 1]`, but at this point, the pixel values in your images are in `[0, 255]`. To rescale them, use the preprocessing method included with the model.

# %%
preprocess_input = tf.keras.applications.mobilenet_v2.preprocess_input

# %% [markdown]
# Note: Alternatively, you could rescale pixel values from `[0, 255]` to `[-1, 1]` using `tf.keras.layers.Rescaling`.

# %%
rescale = tf.keras.layers.Rescaling(1./127.5, offset=-1)

# %% [markdown]
# Note: If using other `tf.keras.applications`, be sure to check the API doc to determine if they expect pixels in `[-1, 1]` or `[0, 1]`, or use the included `preprocess_input` function.

# %% [markdown]
# ## Create the base model from the pre-trained convnets
# You will create the base model from the **MobileNet V2** model developed at Google. This is pre-trained on the ImageNet dataset, a large dataset consisting of 1.4M images and 1000 classes. ImageNet is a research training dataset with a wide variety of categories like `jackfruit` and `syringe`. This base of knowledge will help us classify cats and dogs from our specific dataset.
#
# First, you need to pick which layer of MobileNet V2 you will use for feature extraction. The very last classification layer (on "top", as most diagrams of machine learning models go from bottom to top) is not very useful. Instead, you will follow the common practice to depend on the very last layer before the flatten operation. This layer is called the "bottleneck layer". The bottleneck layer features retain more generality as compared to the final/top layer.
#
# First, instantiate a MobileNet V2 model pre-loaded with weights trained on ImageNet. By specifying the **include_top=False** argument, you load a network that doesn't include the classification layers at the top, which is ideal for feature extraction.

# %%
# Create the base model from the pre-trained model MobileNet V2
IMG_SHAPE = IMG_SIZE + (3,)
base_model = tf.keras.applications.InceptionV3(input_shape=IMG_SHAPE,
                                               include_top=False,
                                               weights='imagenet')

# %% [markdown]
# This feature extractor converts each `160x160x3` image into a `5x5x1280` block of features. Let's see what it does to an example batch of images:

# %%
image_batch, label_batch = next(iter(train_dataset))
feature_batch = base_model(image_batch)
print(feature_batch.shape)
# Out:
# (16, 18, 18, 2048)

# %% [markdown]
# ## Feature extraction
# In this step, you will freeze the convolutional base created from the previous step and to use as a feature extractor. Additionally, you add a classifier on top of it and train the top-level classifier.

# %% [markdown]
# ### Freeze the convolutional base

# %% [markdown]
# It is important to freeze the convolutional base before you compile and train the model. Freezing (by setting layer.trainable = False) prevents the weights in a given layer from being updated during training. MobileNet V2 has many layers, so setting the entire model's `trainable` flag to False will freeze all of them.

# %%
base_model.trainable = False

# %% [markdown]
# ### Important note about BatchNormalization layers
#
# Many models contain `tf.keras.layers.BatchNormalization` layers. This layer is a special case and precautions should be taken in the context of fine-tuning, as shown later in this tutorial.
#
# When you set `layer.trainable = False`, the `BatchNormalization` layer will run in inference mode, and will not update its mean and variance statistics.
#
# When you unfreeze a model that contains BatchNormalization layers in order to do fine-tuning, you should keep the BatchNormalization layers in inference mode by passing `training = False` when calling the base model. Otherwise, the updates applied to the non-trainable weights will destroy what the model has learned.
#
# For more details, see the [Transfer learning guide](https://www.tensorflow.org/guide/keras/transfer_learning).

# %%
# Let's take a look at the base model architecture
base_model.summary()
# Out:
# Model: "inception_v3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_45 (InputLayer)          [(None, 640, 640, 3  0           []
#                                 )]
#
#  conv2d_1786 (Conv2D)           (None, 319, 319, 32  864         ['input_45[0][0]']
#                                 )
#
#  batch_normalization_1786 (Batc  (None, 319, 319, 32  96         ['conv2d_1786[0][0]']
#  hNormalization)                )
#
#  activation_1786 (Activation)   (None, 319, 319, 32  0           ['batch_normalization_1786[0][0]'
#                                 )                                ]
#
#  conv2d_1787 (Conv2D)           (None, 317, 317, 32  9216        ['activation_1786[0][0]']
#                                 )
#
#  batch_normalization_1787 (Batc  (None, 317, 317, 32  96         ['conv2d_1787[0][0]']
#  hNormalization)                )
#
#  activation_1787 (Activation)   (None, 317, 317, 32  0           ['batch_normalization_1787[0][0]'
#                                 )                                ]
#
#  conv2d_1788 (Conv2D)           (None, 317, 317, 64  18432       ['activation_1787[0][0]']
#                                 )
#
#  batch_normalization_1788 (Batc  (None, 317, 317, 64  192        ['conv2d_1788[0][0]']
#  hNormalization)                )
#
#  activation_1788 (Activation)   (None, 317, 317, 64  0           ['batch_normalization_1788[0][0]'
#                                 )                                ]
#
#  max_pooling2d_76 (MaxPooling2D  (None, 158, 158, 64  0          ['activation_1788[0][0]']
#  )                              )
#
#  conv2d_1789 (Conv2D)           (None, 158, 158, 80  5120        ['max_pooling2d_76[0][0]']
#                                 )
#
#  batch_normalization_1789 (Batc  (None, 158, 158, 80  240        ['conv2d_1789[0][0]']
#  hNormalization)                )
#
#  activation_1789 (Activation)   (None, 158, 158, 80  0           ['batch_normalization_1789[0][0]'
#                                 )                                ]
#
#  conv2d_1790 (Conv2D)           (None, 156, 156, 19  138240      ['activation_1789[0][0]']
#                                 2)
#
#  batch_normalization_1790 (Batc  (None, 156, 156, 19  576        ['conv2d_1790[0][0]']
#  hNormalization)                2)
#
#  activation_1790 (Activation)   (None, 156, 156, 19  0           ['batch_normalization_1790[0][0]'
#                                 2)                               ]
#
#  max_pooling2d_77 (MaxPooling2D  (None, 77, 77, 192)  0          ['activation_1790[0][0]']
#  )
#
#  conv2d_1794 (Conv2D)           (None, 77, 77, 64)   12288       ['max_pooling2d_77[0][0]']
#
#  batch_normalization_1794 (Batc  (None, 77, 77, 64)  192         ['conv2d_1794[0][0]']
#  hNormalization)
#
#  activation_1794 (Activation)   (None, 77, 77, 64)   0           ['batch_normalization_1794[0][0]'
#                                                                  ]
#
#  conv2d_1792 (Conv2D)           (None, 77, 77, 48)   9216        ['max_pooling2d_77[0][0]']
#
#  conv2d_1795 (Conv2D)           (None, 77, 77, 96)   55296       ['activation_1794[0][0]']
#
#  batch_normalization_1792 (Batc  (None, 77, 77, 48)  144         ['conv2d_1792[0][0]']
#  hNormalization)
#
#  batch_normalization_1795 (Batc  (None, 77, 77, 96)  288         ['conv2d_1795[0][0]']
#  hNormalization)
#
#  activation_1792 (Activation)   (None, 77, 77, 48)   0           ['batch_normalization_1792[0][0]'
#                                                                  ]
#
#  activation_1795 (Activation)   (None, 77, 77, 96)   0           ['batch_normalization_1795[0][0]'
#                                                                  ]
#
#  average_pooling2d_171 (Average  (None, 77, 77, 192)  0          ['max_pooling2d_77[0][0]']
#  Pooling2D)
#
#  conv2d_1791 (Conv2D)           (None, 77, 77, 64)   12288       ['max_pooling2d_77[0][0]']
#
#  conv2d_1793 (Conv2D)           (None, 77, 77, 64)   76800       ['activation_1792[0][0]']
#
#  conv2d_1796 (Conv2D)           (None, 77, 77, 96)   82944       ['activation_1795[0][0]']
#
#  conv2d_1797 (Conv2D)           (None, 77, 77, 32)   6144        ['average_pooling2d_171[0][0]']
#
#  batch_normalization_1791 (Batc  (None, 77, 77, 64)  192         ['conv2d_1791[0][0]']
#  hNormalization)
#
#  batch_normalization_1793 (Batc  (None, 77, 77, 64)  192         ['conv2d_1793[0][0]']
#  hNormalization)
#
#  batch_normalization_1796 (Batc  (None, 77, 77, 96)  288         ['conv2d_1796[0][0]']
#  hNormalization)
#
#  batch_normalization_1797 (Batc  (None, 77, 77, 32)  96          ['conv2d_1797[0][0]']
#  hNormalization)
#
#  activation_1791 (Activation)   (None, 77, 77, 64)   0           ['batch_normalization_1791[0][0]'
#                                                                  ]
#
#  activation_1793 (Activation)   (None, 77, 77, 64)   0           ['batch_normalization_1793[0][0]'
#                                                                  ]
#
#  activation_1796 (Activation)   (None, 77, 77, 96)   0           ['batch_normalization_1796[0][0]'
#                                                                  ]
#
#  activation_1797 (Activation)   (None, 77, 77, 32)   0           ['batch_normalization_1797[0][0]'
#                                                                  ]
#
#  mixed0 (Concatenate)           (None, 77, 77, 256)  0           ['activation_1791[0][0]',
#                                                                   'activation_1793[0][0]',
#                                                                   'activation_1796[0][0]',
#                                                                   'activation_1797[0][0]']
#
#  conv2d_1801 (Conv2D)           (None, 77, 77, 64)   16384       ['mixed0[0][0]']
#
#  batch_normalization_1801 (Batc  (None, 77, 77, 64)  192         ['conv2d_1801[0][0]']
#  hNormalization)
#
#  activation_1801 (Activation)   (None, 77, 77, 64)   0           ['batch_normalization_1801[0][0]'
#                                                                  ]
#
#  conv2d_1799 (Conv2D)           (None, 77, 77, 48)   12288       ['mixed0[0][0]']
#
#  conv2d_1802 (Conv2D)           (None, 77, 77, 96)   55296       ['activation_1801[0][0]']
#
#  batch_normalization_1799 (Batc  (None, 77, 77, 48)  144         ['conv2d_1799[0][0]']
#  hNormalization)
#
#  batch_normalization_1802 (Batc  (None, 77, 77, 96)  288         ['conv2d_1802[0][0]']
#  hNormalization)
#
#  activation_1799 (Activation)   (None, 77, 77, 48)   0           ['batch_normalization_1799[0][0]'
#                                                                  ]
#
#  activation_1802 (Activation)   (None, 77, 77, 96)   0           ['batch_normalization_1802[0][0]'
#                                                                  ]
#
#  average_pooling2d_172 (Average  (None, 77, 77, 256)  0          ['mixed0[0][0]']
#  Pooling2D)
#
#  conv2d_1798 (Conv2D)           (None, 77, 77, 64)   16384       ['mixed0[0][0]']
#
#  conv2d_1800 (Conv2D)           (None, 77, 77, 64)   76800       ['activation_1799[0][0]']
#
#  conv2d_1803 (Conv2D)           (None, 77, 77, 96)   82944       ['activation_1802[0][0]']
#
#  conv2d_1804 (Conv2D)           (None, 77, 77, 64)   16384       ['average_pooling2d_172[0][0]']
#
#  batch_normalization_1798 (Batc  (None, 77, 77, 64)  192         ['conv2d_1798[0][0]']
#  hNormalization)
#
#  batch_normalization_1800 (Batc  (None, 77, 77, 64)  192         ['conv2d_1800[0][0]']
#  hNormalization)
#
#  batch_normalization_1803 (Batc  (None, 77, 77, 96)  288         ['conv2d_1803[0][0]']
#  hNormalization)
#
#  batch_normalization_1804 (Batc  (None, 77, 77, 64)  192         ['conv2d_1804[0][0]']
#  hNormalization)
#
#  activation_1798 (Activation)   (None, 77, 77, 64)   0           ['batch_normalization_1798[0][0]'
#                                                                  ]
#
#  activation_1800 (Activation)   (None, 77, 77, 64)   0           ['batch_normalization_1800[0][0]'
#                                                                  ]
#
#  activation_1803 (Activation)   (None, 77, 77, 96)   0           ['batch_normalization_1803[0][0]'
#                                                                  ]
#
#  activation_1804 (Activation)   (None, 77, 77, 64)   0           ['batch_normalization_1804[0][0]'
#                                                                  ]
#
#  mixed1 (Concatenate)           (None, 77, 77, 288)  0           ['activation_1798[0][0]',
#                                                                   'activation_1800[0][0]',
#                                                                   'activation_1803[0][0]',
#                                                                   'activation_1804[0][0]']
#
#  conv2d_1808 (Conv2D)           (None, 77, 77, 64)   18432       ['mixed1[0][0]']
#
#  batch_normalization_1808 (Batc  (None, 77, 77, 64)  192         ['conv2d_1808[0][0]']
#  hNormalization)
#
#  activation_1808 (Activation)   (None, 77, 77, 64)   0           ['batch_normalization_1808[0][0]'
#                                                                  ]
#
#  conv2d_1806 (Conv2D)           (None, 77, 77, 48)   13824       ['mixed1[0][0]']
#
#  conv2d_1809 (Conv2D)           (None, 77, 77, 96)   55296       ['activation_1808[0][0]']
#
#  batch_normalization_1806 (Batc  (None, 77, 77, 48)  144         ['conv2d_1806[0][0]']
#  hNormalization)
#
#  batch_normalization_1809 (Batc  (None, 77, 77, 96)  288         ['conv2d_1809[0][0]']
#  hNormalization)
#
#  activation_1806 (Activation)   (None, 77, 77, 48)   0           ['batch_normalization_1806[0][0]'
#                                                                  ]
#
#  activation_1809 (Activation)   (None, 77, 77, 96)   0           ['batch_normalization_1809[0][0]'
#                                                                  ]
#
#  average_pooling2d_173 (Average  (None, 77, 77, 288)  0          ['mixed1[0][0]']
#  Pooling2D)
#
#  conv2d_1805 (Conv2D)           (None, 77, 77, 64)   18432       ['mixed1[0][0]']
#
#  conv2d_1807 (Conv2D)           (None, 77, 77, 64)   76800       ['activation_1806[0][0]']
#
#  conv2d_1810 (Conv2D)           (None, 77, 77, 96)   82944       ['activation_1809[0][0]']
#
#  conv2d_1811 (Conv2D)           (None, 77, 77, 64)   18432       ['average_pooling2d_173[0][0]']
#
#  batch_normalization_1805 (Batc  (None, 77, 77, 64)  192         ['conv2d_1805[0][0]']
#  hNormalization)
#
#  batch_normalization_1807 (Batc  (None, 77, 77, 64)  192         ['conv2d_1807[0][0]']
#  hNormalization)
#
#  batch_normalization_1810 (Batc  (None, 77, 77, 96)  288         ['conv2d_1810[0][0]']
#  hNormalization)
#
#  batch_normalization_1811 (Batc  (None, 77, 77, 64)  192         ['conv2d_1811[0][0]']
#  hNormalization)
#
#  activation_1805 (Activation)   (None, 77, 77, 64)   0           ['batch_normalization_1805[0][0]'
#                                                                  ]
#
#  activation_1807 (Activation)   (None, 77, 77, 64)   0           ['batch_normalization_1807[0][0]'
#                                                                  ]
#
#  activation_1810 (Activation)   (None, 77, 77, 96)   0           ['batch_normalization_1810[0][0]'
#                                                                  ]
#
#  activation_1811 (Activation)   (None, 77, 77, 64)   0           ['batch_normalization_1811[0][0]'
#                                                                  ]
#
#  mixed2 (Concatenate)           (None, 77, 77, 288)  0           ['activation_1805[0][0]',
#                                                                   'activation_1807[0][0]',
#                                                                   'activation_1810[0][0]',
#                                                                   'activation_1811[0][0]']
#
#  conv2d_1813 (Conv2D)           (None, 77, 77, 64)   18432       ['mixed2[0][0]']
#
#  batch_normalization_1813 (Batc  (None, 77, 77, 64)  192         ['conv2d_1813[0][0]']
#  hNormalization)
#
#  activation_1813 (Activation)   (None, 77, 77, 64)   0           ['batch_normalization_1813[0][0]'
#                                                                  ]
#
#  conv2d_1814 (Conv2D)           (None, 77, 77, 96)   55296       ['activation_1813[0][0]']
#
#  batch_normalization_1814 (Batc  (None, 77, 77, 96)  288         ['conv2d_1814[0][0]']
#  hNormalization)
#
#  activation_1814 (Activation)   (None, 77, 77, 96)   0           ['batch_normalization_1814[0][0]'
#                                                                  ]
#
#  conv2d_1812 (Conv2D)           (None, 38, 38, 384)  995328      ['mixed2[0][0]']
#
#  conv2d_1815 (Conv2D)           (None, 38, 38, 96)   82944       ['activation_1814[0][0]']
#
#  batch_normalization_1812 (Batc  (None, 38, 38, 384)  1152       ['conv2d_1812[0][0]']
#  hNormalization)
#
#  batch_normalization_1815 (Batc  (None, 38, 38, 96)  288         ['conv2d_1815[0][0]']
#  hNormalization)
#
#  activation_1812 (Activation)   (None, 38, 38, 384)  0           ['batch_normalization_1812[0][0]'
#                                                                  ]
#
#  activation_1815 (Activation)   (None, 38, 38, 96)   0           ['batch_normalization_1815[0][0]'
#                                                                  ]
#
#  max_pooling2d_78 (MaxPooling2D  (None, 38, 38, 288)  0          ['mixed2[0][0]']
#  )
#
#  mixed3 (Concatenate)           (None, 38, 38, 768)  0           ['activation_1812[0][0]',
#                                                                   'activation_1815[0][0]',
#                                                                   'max_pooling2d_78[0][0]']
#
#  conv2d_1820 (Conv2D)           (None, 38, 38, 128)  98304       ['mixed3[0][0]']
#
#  batch_normalization_1820 (Batc  (None, 38, 38, 128)  384        ['conv2d_1820[0][0]']
#  hNormalization)
#
#  activation_1820 (Activation)   (None, 38, 38, 128)  0           ['batch_normalization_1820[0][0]'
#                                                                  ]
#
#  conv2d_1821 (Conv2D)           (None, 38, 38, 128)  114688      ['activation_1820[0][0]']
#
#  batch_normalization_1821 (Batc  (None, 38, 38, 128)  384        ['conv2d_1821[0][0]']
#  hNormalization)
#
#  activation_1821 (Activation)   (None, 38, 38, 128)  0           ['batch_normalization_1821[0][0]'
#                                                                  ]
#
#  conv2d_1817 (Conv2D)           (None, 38, 38, 128)  98304       ['mixed3[0][0]']
#
#  conv2d_1822 (Conv2D)           (None, 38, 38, 128)  114688      ['activation_1821[0][0]']
#
#  batch_normalization_1817 (Batc  (None, 38, 38, 128)  384        ['conv2d_1817[0][0]']
#  hNormalization)
#
#  batch_normalization_1822 (Batc  (None, 38, 38, 128)  384        ['conv2d_1822[0][0]']
#  hNormalization)
#
#  activation_1817 (Activation)   (None, 38, 38, 128)  0           ['batch_normalization_1817[0][0]'
#                                                                  ]
#
#  activation_1822 (Activation)   (None, 38, 38, 128)  0           ['batch_normalization_1822[0][0]'
#                                                                  ]
#
#  conv2d_1818 (Conv2D)           (None, 38, 38, 128)  114688      ['activation_1817[0][0]']
#
#  conv2d_1823 (Conv2D)           (None, 38, 38, 128)  114688      ['activation_1822[0][0]']
#
#  batch_normalization_1818 (Batc  (None, 38, 38, 128)  384        ['conv2d_1818[0][0]']
#  hNormalization)
#
#  batch_normalization_1823 (Batc  (None, 38, 38, 128)  384        ['conv2d_1823[0][0]']
#  hNormalization)
#
#  activation_1818 (Activation)   (None, 38, 38, 128)  0           ['batch_normalization_1818[0][0]'
#                                                                  ]
#
#  activation_1823 (Activation)   (None, 38, 38, 128)  0           ['batch_normalization_1823[0][0]'
#                                                                  ]
#
#  average_pooling2d_174 (Average  (None, 38, 38, 768)  0          ['mixed3[0][0]']
#  Pooling2D)
#
#  conv2d_1816 (Conv2D)           (None, 38, 38, 192)  147456      ['mixed3[0][0]']
#
#  conv2d_1819 (Conv2D)           (None, 38, 38, 192)  172032      ['activation_1818[0][0]']
#
#  conv2d_1824 (Conv2D)           (None, 38, 38, 192)  172032      ['activation_1823[0][0]']
#
#  conv2d_1825 (Conv2D)           (None, 38, 38, 192)  147456      ['average_pooling2d_174[0][0]']
#
#  batch_normalization_1816 (Batc  (None, 38, 38, 192)  576        ['conv2d_1816[0][0]']
#  hNormalization)
#
#  batch_normalization_1819 (Batc  (None, 38, 38, 192)  576        ['conv2d_1819[0][0]']
#  hNormalization)
#
#  batch_normalization_1824 (Batc  (None, 38, 38, 192)  576        ['conv2d_1824[0][0]']
#  hNormalization)
#
#  batch_normalization_1825 (Batc  (None, 38, 38, 192)  576        ['conv2d_1825[0][0]']
#  hNormalization)
#
#  activation_1816 (Activation)   (None, 38, 38, 192)  0           ['batch_normalization_1816[0][0]'
#                                                                  ]
#
#  activation_1819 (Activation)   (None, 38, 38, 192)  0           ['batch_normalization_1819[0][0]'
#                                                                  ]
#
#  activation_1824 (Activation)   (None, 38, 38, 192)  0           ['batch_normalization_1824[0][0]'
#                                                                  ]
#
#  activation_1825 (Activation)   (None, 38, 38, 192)  0           ['batch_normalization_1825[0][0]'
#                                                                  ]
#
#  mixed4 (Concatenate)           (None, 38, 38, 768)  0           ['activation_1816[0][0]',
#                                                                   'activation_1819[0][0]',
#                                                                   'activation_1824[0][0]',
#                                                                   'activation_1825[0][0]']
#
#  conv2d_1830 (Conv2D)           (None, 38, 38, 160)  122880      ['mixed4[0][0]']
#
#  batch_normalization_1830 (Batc  (None, 38, 38, 160)  480        ['conv2d_1830[0][0]']
#  hNormalization)
#
#  activation_1830 (Activation)   (None, 38, 38, 160)  0           ['batch_normalization_1830[0][0]'
#                                                                  ]
#
#  conv2d_1831 (Conv2D)           (None, 38, 38, 160)  179200      ['activation_1830[0][0]']
#
#  batch_normalization_1831 (Batc  (None, 38, 38, 160)  480        ['conv2d_1831[0][0]']
#  hNormalization)
#
#  activation_1831 (Activation)   (None, 38, 38, 160)  0           ['batch_normalization_1831[0][0]'
#                                                                  ]
#
#  conv2d_1827 (Conv2D)           (None, 38, 38, 160)  122880      ['mixed4[0][0]']
#
#  conv2d_1832 (Conv2D)           (None, 38, 38, 160)  179200      ['activation_1831[0][0]']
#
#  batch_normalization_1827 (Batc  (None, 38, 38, 160)  480        ['conv2d_1827[0][0]']
#  hNormalization)
#
#  batch_normalization_1832 (Batc  (None, 38, 38, 160)  480        ['conv2d_1832[0][0]']
#  hNormalization)
#
#  activation_1827 (Activation)   (None, 38, 38, 160)  0           ['batch_normalization_1827[0][0]'
#                                                                  ]
#
#  activation_1832 (Activation)   (None, 38, 38, 160)  0           ['batch_normalization_1832[0][0]'
#                                                                  ]
#
#  conv2d_1828 (Conv2D)           (None, 38, 38, 160)  179200      ['activation_1827[0][0]']
#
#  conv2d_1833 (Conv2D)           (None, 38, 38, 160)  179200      ['activation_1832[0][0]']
#
#  batch_normalization_1828 (Batc  (None, 38, 38, 160)  480        ['conv2d_1828[0][0]']
#  hNormalization)
#
#  batch_normalization_1833 (Batc  (None, 38, 38, 160)  480        ['conv2d_1833[0][0]']
#  hNormalization)
#
#  activation_1828 (Activation)   (None, 38, 38, 160)  0           ['batch_normalization_1828[0][0]'
#                                                                  ]
#
#  activation_1833 (Activation)   (None, 38, 38, 160)  0           ['batch_normalization_1833[0][0]'
#                                                                  ]
#
#  average_pooling2d_175 (Average  (None, 38, 38, 768)  0          ['mixed4[0][0]']
#  Pooling2D)
#
#  conv2d_1826 (Conv2D)           (None, 38, 38, 192)  147456      ['mixed4[0][0]']
#
#  conv2d_1829 (Conv2D)           (None, 38, 38, 192)  215040      ['activation_1828[0][0]']
#
#  conv2d_1834 (Conv2D)           (None, 38, 38, 192)  215040      ['activation_1833[0][0]']
#
#  conv2d_1835 (Conv2D)           (None, 38, 38, 192)  147456      ['average_pooling2d_175[0][0]']
#
#  batch_normalization_1826 (Batc  (None, 38, 38, 192)  576        ['conv2d_1826[0][0]']
#  hNormalization)
#
#  batch_normalization_1829 (Batc  (None, 38, 38, 192)  576        ['conv2d_1829[0][0]']
#  hNormalization)
#
#  batch_normalization_1834 (Batc  (None, 38, 38, 192)  576        ['conv2d_1834[0][0]']
#  hNormalization)
#
#  batch_normalization_1835 (Batc  (None, 38, 38, 192)  576        ['conv2d_1835[0][0]']
#  hNormalization)
#
#  activation_1826 (Activation)   (None, 38, 38, 192)  0           ['batch_normalization_1826[0][0]'
#                                                                  ]
#
#  activation_1829 (Activation)   (None, 38, 38, 192)  0           ['batch_normalization_1829[0][0]'
#                                                                  ]
#
#  activation_1834 (Activation)   (None, 38, 38, 192)  0           ['batch_normalization_1834[0][0]'
#                                                                  ]
#
#  activation_1835 (Activation)   (None, 38, 38, 192)  0           ['batch_normalization_1835[0][0]'
#                                                                  ]
#
#  mixed5 (Concatenate)           (None, 38, 38, 768)  0           ['activation_1826[0][0]',
#                                                                   'activation_1829[0][0]',
#                                                                   'activation_1834[0][0]',
#                                                                   'activation_1835[0][0]']
#
#  conv2d_1840 (Conv2D)           (None, 38, 38, 160)  122880      ['mixed5[0][0]']
#
#  batch_normalization_1840 (Batc  (None, 38, 38, 160)  480        ['conv2d_1840[0][0]']
#  hNormalization)
#
#  activation_1840 (Activation)   (None, 38, 38, 160)  0           ['batch_normalization_1840[0][0]'
#                                                                  ]
#
#  conv2d_1841 (Conv2D)           (None, 38, 38, 160)  179200      ['activation_1840[0][0]']
#
#  batch_normalization_1841 (Batc  (None, 38, 38, 160)  480        ['conv2d_1841[0][0]']
#  hNormalization)
#
#  activation_1841 (Activation)   (None, 38, 38, 160)  0           ['batch_normalization_1841[0][0]'
#                                                                  ]
#
#  conv2d_1837 (Conv2D)           (None, 38, 38, 160)  122880      ['mixed5[0][0]']
#
#  conv2d_1842 (Conv2D)           (None, 38, 38, 160)  179200      ['activation_1841[0][0]']
#
# ...
#
#  batch_normalization_1867 (Batc  (None, 18, 18, 384)  1152       ['conv2d_1867[0][0]']
#  hNormalization)
#
#  activation_1863 (Activation)   (None, 18, 18, 384)  0           ['batch_normalization_1863[0][0]'
#                                                                  ]
#
#  activation_1867 (Activation)   (None, 18, 18, 384)  0           ['batch_normalization_1867[0][0]'
#                                                                  ]
#
#  conv2d_1864 (Conv2D)           (None, 18, 18, 384)  442368      ['activation_1863[0][0]']
#
#  conv2d_1865 (Conv2D)           (None, 18, 18, 384)  442368      ['activation_1863[0][0]']
#
#  conv2d_1868 (Conv2D)           (None, 18, 18, 384)  442368      ['activation_1867[0][0]']
#
#  conv2d_1869 (Conv2D)           (None, 18, 18, 384)  442368      ['activation_1867[0][0]']
#
#  average_pooling2d_178 (Average  (None, 18, 18, 1280  0          ['mixed8[0][0]']
#  Pooling2D)                     )
#
#  conv2d_1862 (Conv2D)           (None, 18, 18, 320)  409600      ['mixed8[0][0]']
#
#  batch_normalization_1864 (Batc  (None, 18, 18, 384)  1152       ['conv2d_1864[0][0]']
#  hNormalization)
#
#  batch_normalization_1865 (Batc  (None, 18, 18, 384)  1152       ['conv2d_1865[0][0]']
#  hNormalization)
#
#  batch_normalization_1868 (Batc  (None, 18, 18, 384)  1152       ['conv2d_1868[0][0]']
#  hNormalization)
#
#  batch_normalization_1869 (Batc  (None, 18, 18, 384)  1152       ['conv2d_1869[0][0]']
#  hNormalization)
#
#  conv2d_1870 (Conv2D)           (None, 18, 18, 192)  245760      ['average_pooling2d_178[0][0]']
#
#  batch_normalization_1862 (Batc  (None, 18, 18, 320)  960        ['conv2d_1862[0][0]']
#  hNormalization)
#
#  activation_1864 (Activation)   (None, 18, 18, 384)  0           ['batch_normalization_1864[0][0]'
#                                                                  ]
#
#  activation_1865 (Activation)   (None, 18, 18, 384)  0           ['batch_normalization_1865[0][0]'
#                                                                  ]
#
#  activation_1868 (Activation)   (None, 18, 18, 384)  0           ['batch_normalization_1868[0][0]'
#                                                                  ]
#
#  activation_1869 (Activation)   (None, 18, 18, 384)  0           ['batch_normalization_1869[0][0]'
#                                                                  ]
#
#  batch_normalization_1870 (Batc  (None, 18, 18, 192)  576        ['conv2d_1870[0][0]']
#  hNormalization)
#
#  activation_1862 (Activation)   (None, 18, 18, 320)  0           ['batch_normalization_1862[0][0]'
#                                                                  ]
#
#  mixed9_0 (Concatenate)         (None, 18, 18, 768)  0           ['activation_1864[0][0]',
#                                                                   'activation_1865[0][0]']
#
#  concatenate_38 (Concatenate)   (None, 18, 18, 768)  0           ['activation_1868[0][0]',
#                                                                   'activation_1869[0][0]']
#
#  activation_1870 (Activation)   (None, 18, 18, 192)  0           ['batch_normalization_1870[0][0]'
#                                                                  ]
#
#  mixed9 (Concatenate)           (None, 18, 18, 2048  0           ['activation_1862[0][0]',
#                                 )                                 'mixed9_0[0][0]',
#                                                                   'concatenate_38[0][0]',
#                                                                   'activation_1870[0][0]']
#
#  conv2d_1875 (Conv2D)           (None, 18, 18, 448)  917504      ['mixed9[0][0]']
#
#  batch_normalization_1875 (Batc  (None, 18, 18, 448)  1344       ['conv2d_1875[0][0]']
#  hNormalization)
#
#  activation_1875 (Activation)   (None, 18, 18, 448)  0           ['batch_normalization_1875[0][0]'
#                                                                  ]
#
#  conv2d_1872 (Conv2D)           (None, 18, 18, 384)  786432      ['mixed9[0][0]']
#
#  conv2d_1876 (Conv2D)           (None, 18, 18, 384)  1548288     ['activation_1875[0][0]']
#
#  batch_normalization_1872 (Batc  (None, 18, 18, 384)  1152       ['conv2d_1872[0][0]']
#  hNormalization)
#
#  batch_normalization_1876 (Batc  (None, 18, 18, 384)  1152       ['conv2d_1876[0][0]']
#  hNormalization)
#
#  activation_1872 (Activation)   (None, 18, 18, 384)  0           ['batch_normalization_1872[0][0]'
#                                                                  ]
#
#  activation_1876 (Activation)   (None, 18, 18, 384)  0           ['batch_normalization_1876[0][0]'
#                                                                  ]
#
#  conv2d_1873 (Conv2D)           (None, 18, 18, 384)  442368      ['activation_1872[0][0]']
#
#  conv2d_1874 (Conv2D)           (None, 18, 18, 384)  442368      ['activation_1872[0][0]']
#
#  conv2d_1877 (Conv2D)           (None, 18, 18, 384)  442368      ['activation_1876[0][0]']
#
#  conv2d_1878 (Conv2D)           (None, 18, 18, 384)  442368      ['activation_1876[0][0]']
#
#  average_pooling2d_179 (Average  (None, 18, 18, 2048  0          ['mixed9[0][0]']
#  Pooling2D)                     )
#
#  conv2d_1871 (Conv2D)           (None, 18, 18, 320)  655360      ['mixed9[0][0]']
#
#  batch_normalization_1873 (Batc  (None, 18, 18, 384)  1152       ['conv2d_1873[0][0]']
#  hNormalization)
#
#  batch_normalization_1874 (Batc  (None, 18, 18, 384)  1152       ['conv2d_1874[0][0]']
#  hNormalization)
#
#  batch_normalization_1877 (Batc  (None, 18, 18, 384)  1152       ['conv2d_1877[0][0]']
#  hNormalization)
#
#  batch_normalization_1878 (Batc  (None, 18, 18, 384)  1152       ['conv2d_1878[0][0]']
#  hNormalization)
#
#  conv2d_1879 (Conv2D)           (None, 18, 18, 192)  393216      ['average_pooling2d_179[0][0]']
#
#  batch_normalization_1871 (Batc  (None, 18, 18, 320)  960        ['conv2d_1871[0][0]']
#  hNormalization)
#
#  activation_1873 (Activation)   (None, 18, 18, 384)  0           ['batch_normalization_1873[0][0]'
#                                                                  ]
#
#  activation_1874 (Activation)   (None, 18, 18, 384)  0           ['batch_normalization_1874[0][0]'
#                                                                  ]
#
#  activation_1877 (Activation)   (None, 18, 18, 384)  0           ['batch_normalization_1877[0][0]'
#                                                                  ]
#
#  activation_1878 (Activation)   (None, 18, 18, 384)  0           ['batch_normalization_1878[0][0]'
#                                                                  ]
#
#  batch_normalization_1879 (Batc  (None, 18, 18, 192)  576        ['conv2d_1879[0][0]']
#  hNormalization)
#
#  activation_1871 (Activation)   (None, 18, 18, 320)  0           ['batch_normalization_1871[0][0]'
#                                                                  ]
#
#  mixed9_1 (Concatenate)         (None, 18, 18, 768)  0           ['activation_1873[0][0]',
#                                                                   'activation_1874[0][0]']
#
#  concatenate_39 (Concatenate)   (None, 18, 18, 768)  0           ['activation_1877[0][0]',
#                                                                   'activation_1878[0][0]']
#
#  activation_1879 (Activation)   (None, 18, 18, 192)  0           ['batch_normalization_1879[0][0]'
#                                                                  ]
#
#  mixed10 (Concatenate)          (None, 18, 18, 2048  0           ['activation_1871[0][0]',
#                                 )                                 'mixed9_1[0][0]',
#                                                                   'concatenate_39[0][0]',
#                                                                   'activation_1879[0][0]']
#
# ==================================================================================================
# Total params: 21,802,784
# Trainable params: 0
# Non-trainable params: 21,802,784
# __________________________________________________________________________________________________

# %% [markdown]
# ### Add a classification head

# %% [markdown]
# To generate predictions from the block of features, average over the spatial `5x5` spatial locations, using a `tf.keras.layers.GlobalAveragePooling2D` layer to convert the features to  a single 1280-element vector per image.

# %%
global_average_layer = tf.keras.layers.GlobalAveragePooling2D()
feature_batch_average = global_average_layer(feature_batch)
print(feature_batch_average.shape)
# Out:
# (16, 2048)

# %% [markdown]
# Apply a `tf.keras.layers.Dense` layer to convert these features into a single prediction per image. You don't need an activation function here because this prediction will be treated as a `logit`, or a raw prediction value. Positive numbers predict class 1, negative numbers predict class 0.

# %%
prediction_layer = tf.keras.layers.Dense(6)
prediction_batch = prediction_layer(feature_batch_average)
print(prediction_batch.shape)
# Out:
# (16, 6)

# %% [markdown]
# Build a model by chaining together the data augmentation, rescaling, `base_model` and feature extractor layers using the [Keras Functional API](https://www.tensorflow.org/guide/keras/functional). As previously mentioned, use `training=False` as our model contains a `BatchNormalization` layer.

# %%
inputs = tf.keras.Input(shape=(640, 640, 3))
x = data_augmentation(inputs)
x = preprocess_input(x)
x = base_model(x, training=True)
x = global_average_layer(x)
x = tf.keras.layers.Dropout(0.2)(x)
outputs = prediction_layer(x)
model = tf.keras.Model(inputs, outputs)

# %% [markdown]
# ### Compile the model
#
# Compile the model before training it. Since there are two classes, use the `tf.keras.losses.BinaryCrossentropy` loss with `from_logits=True` since the model provides a linear output.

# %%
base_learning_rate = 0.005
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=base_learning_rate),
              loss=tf.keras.losses.CategoricalCrossentropy(from_logits='softmax'),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "model_21"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_46 (InputLayer)       [(None, 640, 640, 3)]     0
#
#  sequential_25 (Sequential)  (None, 640, 640, 3)       0
#
#  tf.math.truediv_21 (TFOpLam  (None, 640, 640, 3)      0
#  bda)
#
#  tf.math.subtract_21 (TFOpLa  (None, 640, 640, 3)      0
#  mbda)
#
#  inception_v3 (Functional)   (None, 18, 18, 2048)      21802784
#
#  global_average_pooling2d_21  (None, 2048)             0
#   (GlobalAveragePooling2D)
#
#  dropout_21 (Dropout)        (None, 2048)              0
#
#  dense_22 (Dense)            (None, 6)                 12294
#
# =================================================================
# Total params: 21,815,078
# Trainable params: 12,294
# Non-trainable params: 21,802,784
# _________________________________________________________________

# %% [markdown]
# The 2.5 million parameters in MobileNet are frozen, but there are 1.2 thousand _trainable_ parameters in the Dense layer. These are divided between two `tf.Variable` objects, the weights and biases.

# %%
len(model.trainable_variables)
# Out:
# 2

# %% [markdown]
# ### Train the model
#
# After training for 10 epochs, you should see ~94% accuracy on the validation set.

# %%
initial_epochs = 50

loss0, accuracy0 = model.evaluate(validation_dataset)
# Out:
# 4/4 [==============================] - 6s 1s/step - loss: 1.7705 - accuracy: 0.2167

# %%
print("initial loss: {:.2f}".format(loss0))
print("initial accuracy: {:.2f}".format(accuracy0))
# Out:
# initial loss: 1.77
# initial accuracy: 0.22

# %%
history = model.fit(train_dataset,
                    epochs=initial_epochs,
                    validation_data=validation_dataset)
# Out:
# Epoch 1/50
# 15/15 [==============================] - 11s 386ms/step - loss: 1.6267 - accuracy: 0.3333 - val_loss: 1.2828 - val_accuracy: 0.6167
# Epoch 2/50
# 15/15 [==============================] - 6s 387ms/step - loss: 0.8910 - accuracy: 0.7750 - val_loss: 1.1634 - val_accuracy: 0.5667
# Epoch 3/50
# 15/15 [==============================] - 6s 388ms/step - loss: 0.6133 - accuracy: 0.8583 - val_loss: 0.8319 - val_accuracy: 0.7167
# Epoch 4/50
# 15/15 [==============================] - 6s 392ms/step - loss: 0.4527 - accuracy: 0.9000 - val_loss: 0.7915 - val_accuracy: 0.7167
# Epoch 5/50
# 15/15 [==============================] - 6s 393ms/step - loss: 0.3592 - accuracy: 0.9125 - val_loss: 0.9130 - val_accuracy: 0.7500
# Epoch 6/50
# 15/15 [==============================] - 6s 394ms/step - loss: 0.3071 - accuracy: 0.9458 - val_loss: 0.6946 - val_accuracy: 0.7500
# Epoch 7/50
# 15/15 [==============================] - 6s 393ms/step - loss: 0.2850 - accuracy: 0.9292 - val_loss: 0.6995 - val_accuracy: 0.8000
# Epoch 8/50
# 15/15 [==============================] - 6s 395ms/step - loss: 0.2401 - accuracy: 0.9542 - val_loss: 0.6255 - val_accuracy: 0.7500
# Epoch 9/50
# 15/15 [==============================] - 6s 396ms/step - loss: 0.2354 - accuracy: 0.9542 - val_loss: 0.4658 - val_accuracy: 0.8667
# Epoch 10/50
# 15/15 [==============================] - 6s 400ms/step - loss: 0.1751 - accuracy: 0.9708 - val_loss: 0.4816 - val_accuracy: 0.8667
# Epoch 11/50
# 15/15 [==============================] - 7s 398ms/step - loss: 0.2016 - accuracy: 0.9500 - val_loss: 0.5263 - val_accuracy: 0.7833
# Epoch 12/50
# 15/15 [==============================] - 7s 398ms/step - loss: 0.1738 - accuracy: 0.9750 - val_loss: 0.4836 - val_accuracy: 0.7667
# Epoch 13/50
# 15/15 [==============================] - 6s 397ms/step - loss: 0.1720 - accuracy: 0.9583 - val_loss: 0.4329 - val_accuracy: 0.8667
# Epoch 14/50
# 15/15 [==============================] - 7s 404ms/step - loss: 0.1591 - accuracy: 0.9667 - val_loss: 0.3858 - val_accuracy: 0.8500
# Epoch 15/50
# 15/15 [==============================] - 6s 400ms/step - loss: 0.1361 - accuracy: 0.9792 - val_loss: 0.3925 - val_accuracy: 0.8833
# Epoch 16/50
# 15/15 [==============================] - 7s 395ms/step - loss: 0.1476 - accuracy: 0.9625 - val_loss: 0.3867 - val_accuracy: 0.8500
# Epoch 17/50
# 15/15 [==============================] - 6s 397ms/step - loss: 0.1324 - accuracy: 0.9833 - val_loss: 0.3346 - val_accuracy: 0.8500
# Epoch 18/50
# 15/15 [==============================] - 6s 398ms/step - loss: 0.1070 - accuracy: 0.9792 - val_loss: 0.3278 - val_accuracy: 0.8833
# Epoch 19/50
# 15/15 [==============================] - 7s 400ms/step - loss: 0.1212 - accuracy: 0.9708 - val_loss: 0.2789 - val_accuracy: 0.9167
# Epoch 20/50
# 15/15 [==============================] - 7s 399ms/step - loss: 0.0903 - accuracy: 0.9958 - val_loss: 0.2832 - val_accuracy: 0.9167
# Epoch 21/50
# 15/15 [==============================] - 7s 400ms/step - loss: 0.0989 - accuracy: 0.9792 - val_loss: 0.2733 - val_accuracy: 0.9333
# Epoch 22/50
# 15/15 [==============================] - 7s 402ms/step - loss: 0.1099 - accuracy: 0.9792 - val_loss: 0.2722 - val_accuracy: 0.9333
# Epoch 23/50
# 15/15 [==============================] - 7s 399ms/step - loss: 0.0884 - accuracy: 0.9875 - val_loss: 0.2424 - val_accuracy: 0.9333
# Epoch 24/50
# 15/15 [==============================] - 6s 396ms/step - loss: 0.0980 - accuracy: 0.9792 - val_loss: 0.2686 - val_accuracy: 0.9333
# Epoch 25/50
# 15/15 [==============================] - 6s 399ms/step - loss: 0.0718 - accuracy: 0.9958 - val_loss: 0.2603 - val_accuracy: 0.9333
# Epoch 26/50
# 15/15 [==============================] - 6s 398ms/step - loss: 0.0824 - accuracy: 0.9958 - val_loss: 0.2497 - val_accuracy: 0.9333
# Epoch 27/50
# 15/15 [==============================] - 6s 401ms/step - loss: 0.0836 - accuracy: 0.9792 - val_loss: 0.2435 - val_accuracy: 0.9500
# Epoch 28/50
# 15/15 [==============================] - 7s 402ms/step - loss: 0.0960 - accuracy: 0.9792 - val_loss: 0.2258 - val_accuracy: 0.9500
# Epoch 29/50
# 15/15 [==============================] - 7s 398ms/step - loss: 0.0908 - accuracy: 0.9875 - val_loss: 0.2198 - val_accuracy: 0.9333
# Epoch 30/50
# 15/15 [==============================] - 6s 399ms/step - loss: 0.0853 - accuracy: 0.9875 - val_loss: 0.2199 - val_accuracy: 0.9500
# Epoch 31/50
# 15/15 [==============================] - 7s 397ms/step - loss: 0.0727 - accuracy: 0.9917 - val_loss: 0.2549 - val_accuracy: 0.9333
# Epoch 32/50
# 15/15 [==============================] - 6s 399ms/step - loss: 0.0584 - accuracy: 0.9875 - val_loss: 0.2263 - val_accuracy: 0.9333
# Epoch 33/50
# 15/15 [==============================] - 6s 400ms/step - loss: 0.0616 - accuracy: 1.0000 - val_loss: 0.2101 - val_accuracy: 0.9500
# Epoch 34/50
# 15/15 [==============================] - 7s 398ms/step - loss: 0.0802 - accuracy: 0.9667 - val_loss: 0.2097 - val_accuracy: 0.9333
# Epoch 35/50
# 15/15 [==============================] - 6s 399ms/step - loss: 0.0728 - accuracy: 0.9792 - val_loss: 0.2185 - val_accuracy: 0.9667
# Epoch 36/50
# 15/15 [==============================] - 7s 401ms/step - loss: 0.0673 - accuracy: 0.9875 - val_loss: 0.1821 - val_accuracy: 0.9500
# Epoch 37/50
# 15/15 [==============================] - 7s 397ms/step - loss: 0.0961 - accuracy: 0.9708 - val_loss: 0.2015 - val_accuracy: 0.9500
# Epoch 38/50
# 15/15 [==============================] - 6s 398ms/step - loss: 0.0458 - accuracy: 1.0000 - val_loss: 0.1777 - val_accuracy: 0.9667
# Epoch 39/50
# 15/15 [==============================] - 7s 398ms/step - loss: 0.0655 - accuracy: 0.9833 - val_loss: 0.1802 - val_accuracy: 0.9500
# Epoch 40/50
# 15/15 [==============================] - 6s 400ms/step - loss: 0.0594 - accuracy: 0.9917 - val_loss: 0.1728 - val_accuracy: 0.9500
# Epoch 41/50
# 15/15 [==============================] - 7s 401ms/step - loss: 0.0508 - accuracy: 0.9958 - val_loss: 0.1618 - val_accuracy: 0.9500
# Epoch 42/50
# 15/15 [==============================] - 7s 405ms/step - loss: 0.0362 - accuracy: 1.0000 - val_loss: 0.1744 - val_accuracy: 0.9667
# Epoch 43/50
# 15/15 [==============================] - 7s 400ms/step - loss: 0.0444 - accuracy: 0.9917 - val_loss: 0.1542 - val_accuracy: 0.9667
# Epoch 44/50
# 15/15 [==============================] - 6s 398ms/step - loss: 0.0421 - accuracy: 1.0000 - val_loss: 0.1636 - val_accuracy: 0.9500
# Epoch 45/50
# 15/15 [==============================] - 6s 399ms/step - loss: 0.0543 - accuracy: 0.9917 - val_loss: 0.1625 - val_accuracy: 0.9500
# Epoch 46/50
# 15/15 [==============================] - 6s 397ms/step - loss: 0.0608 - accuracy: 0.9917 - val_loss: 0.1620 - val_accuracy: 0.9667
# Epoch 47/50
# 15/15 [==============================] - 6s 395ms/step - loss: 0.0602 - accuracy: 0.9875 - val_loss: 0.1513 - val_accuracy: 0.9667
# Epoch 48/50
# 15/15 [==============================] - 6s 397ms/step - loss: 0.0395 - accuracy: 1.0000 - val_loss: 0.1810 - val_accuracy: 0.9500
# Epoch 49/50
# 15/15 [==============================] - 6s 398ms/step - loss: 0.0447 - accuracy: 0.9958 - val_loss: 0.1548 - val_accuracy: 0.9667
# Epoch 50/50
# 15/15 [==============================] - 7s 402ms/step - loss: 0.0416 - accuracy: 0.9958 - val_loss: 0.1609 - val_accuracy: 0.9500

# %% [markdown]
# ### Learning curves
#
# Let's take a look at the learning curves of the training and validation accuracy/loss when using the MobileNetV2 base model as a fixed feature extractor.

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,1.0])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %% [markdown]
# Note: If you are wondering why the validation metrics are clearly better than the training metrics, the main factor is because layers like `tf.keras.layers.BatchNormalization` and `tf.keras.layers.Dropout` affect accuracy during training. They are turned off when calculating validation loss.
#
# To a lesser extent, it is also because training metrics report the average for an epoch, while validation metrics are evaluated after the epoch, so validation metrics see a model that has trained slightly longer.

# %% [markdown]
# ## Fine tuning
# In the feature extraction experiment, you were only training a few layers on top of an MobileNetV2 base model. The weights of the pre-trained network were **not** updated during training.
#
# One way to increase performance even further is to train (or "fine-tune") the weights of the top layers of the pre-trained model alongside the training of the classifier you added. The training process will force the weights to be tuned from generic feature maps to features associated specifically with the dataset.
#
# Note: This should only be attempted after you have trained the top-level classifier with the pre-trained model set to non-trainable. If you add a randomly initialized classifier on top of a pre-trained model and attempt to train all layers jointly, the magnitude of the gradient updates will be too large (due to the random weights from the classifier) and your pre-trained model will forget what it has learned.
#
# Also, you should try to fine-tune a small number of top layers rather than the whole MobileNet model. In most convolutional networks, the higher up a layer is, the more specialized it is. The first few layers learn very simple and generic features that generalize to almost all types of images. As you go higher up, the features are increasingly more specific to the dataset on which the model was trained. The goal of fine-tuning is to adapt these specialized features to work with the new dataset, rather than overwrite the generic learning.

# %% [markdown]
# ### Un-freeze the top layers of the model

# %% [markdown]
# All you need to do is unfreeze the `base_model` and set the bottom layers to be un-trainable. Then, you should recompile the model (necessary for these changes to take effect), and resume training.

# %%
# base_model.trainable = True

# %%
# Let's take a look to see how many layers are in the base model
# print("Number of layers in the base model: ", len(base_model.layers))

# # Fine-tune from this layer onwards
# fine_tune_at = 10

# # Freeze all the layers before the `fine_tune_at` layer
# for layer in base_model.layers[:fine_tune_at]:
#   layer.trainable = False

# %% [markdown]
# ### Compile the model
#
# As you are training a much larger model and want to readapt the pretrained weights, it is important to use a lower learning rate at this stage. Otherwise, your model could overfit very quickly.

# %%
# model.compile(loss=tf.keras.losses.CategoricalCrossentropy(),
#               optimizer = tf.keras.optimizers.Adam(learning_rate=base_learning_rate/10),
#               metrics=['accuracy'])

# %%
# model.summary()

# %%
# len(model.trainable_variables)

# %% [markdown]
# ### Continue training the model

# %% [markdown]
# If you trained to convergence earlier, this step will improve your accuracy by a few percentage points.

# %%
# fine_tune_epochs = 10
# total_epochs =  initial_epochs + fine_tune_epochs

# history_fine = model.fit(train_dataset,
#                          epochs=total_epochs,
#                          initial_epoch=history.epoch[-1],
#                          validation_data=validation_dataset)

# %% [markdown]
# Let's take a look at the learning curves of the training and validation accuracy/loss when fine-tuning the last few layers of the MobileNetV2 base model and training the classifier on top of it. The validation loss is much higher than the training loss, so you may get some overfitting.
#
# You may also get some overfitting as the new training set is relatively small and similar to the original MobileNetV2 datasets.

# %% [markdown]
# After fine tuning the model nearly reaches 98% accuracy on the validation set.

# %%
# acc += history_fine.history['accuracy']
# val_acc += history_fine.history['val_accuracy']

# loss += history_fine.history['loss']
# val_loss += history_fine.history['val_loss']

# %%
# plt.figure(figsize=(8, 8))
# plt.subplot(2, 1, 1)
# plt.plot(acc, label='Training Accuracy')
# plt.plot(val_acc, label='Validation Accuracy')
# plt.ylim([0.8, 1])
# plt.plot([initial_epochs-1,initial_epochs-1],
#           plt.ylim(), label='Start Fine Tuning')
# plt.legend(loc='lower right')
# plt.title('Training and Validation Accuracy')

# plt.subplot(2, 1, 2)
# plt.plot(loss, label='Training Loss')
# plt.plot(val_loss, label='Validation Loss')
# plt.ylim([0, 1.0])
# plt.plot([initial_epochs-1,initial_epochs-1],
#          plt.ylim(), label='Start Fine Tuning')
# plt.legend(loc='upper right')
# plt.title('Training and Validation Loss')
# plt.xlabel('epoch')
# plt.show()

# %% [markdown]
# ### Evaluation and prediction

# %% [markdown]
# Finally you can verify the performance of the model on new data using test set.

# %%
loss, accuracy = model.evaluate(test_dataset)
print('Test accuracy :', accuracy)
# Out:
# 1/1 [==============================] - 1s 555ms/step - loss: 0.0906 - accuracy: 1.0000
# Test accuracy : 1.0

# %% [markdown]
# And now you are all set to use this model to predict if your pet is a cat or dog.

# %%
class_names
# Out:
# ['differentiation', 'finite', 'inequality', 'integral', 'limit', 'linear']

# %%
# Retrieve a batch of images from the test set
image_batch, label_batch = test_dataset.as_numpy_iterator().next()
predictions = model.predict_on_batch(image_batch)

# Apply a sigmoid since our model returns logits
predictions = tf.nn.sigmoid(predictions)
predictions = tf.where(predictions < 0.5, 0, 1)
# predictions
# print('Predictions:\n', predictions.numpy())
# print('Labels:\n', label_batch)

plt.figure(figsize=(15, 15))
for i in range(16):
  ax = plt.subplot(4, 4, i + 1)
  plt.imshow(image_batch[i].astype("uint8"))
  # print(predictions[i])
  plt.title(class_names[np.argmax(predictions[i])])
  plt.axis("off")

# %% [markdown]
# ## Summary
#
# * **Using a pre-trained model for feature extraction**:  When working with a small dataset, it is a common practice to take advantage of features learned by a model trained on a larger dataset in the same domain. This is done by instantiating the pre-trained model and adding a fully-connected classifier on top. The pre-trained model is "frozen" and only the weights of the classifier get updated during training.
# In this case, the convolutional base extracted all the features associated with each image and you just trained a classifier that determines the image class given that set of extracted features.
#
# * **Fine-tuning a pre-trained model**: To further improve performance, one might want to repurpose the top-level layers of the pre-trained models to the new dataset via fine-tuning.
# In this case, you tuned your weights such that your model learned high-level features specific to the dataset. This technique is usually recommended when the training dataset is large and very similar to the original dataset that the pre-trained model was trained on.
#
# To learn more, visit the [Transfer learning guide](https://www.tensorflow.org/guide/keras/transfer_learning).
